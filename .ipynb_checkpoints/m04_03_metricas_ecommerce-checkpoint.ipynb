# %% [markdown]
# # Modulo 04 - Modelo de Negócio e Métricas

# %% [markdown]
# ## 3 - As métricas de um e-commerce

# %%
from IPython.display import Image
PATH = 'photos/E-commerce.png'
Image( filename = PATH, width=800, height=400)

# %% [markdown]
# ### 3.1 - Métricas de Crescimento

# %% [markdown]
# 1. Porcentagem do Marketshare
# 2. Número de Clientes Novos

# %% [markdown]
# ### 3.2 - Métricas de Faturamento

# %% [markdown]
# 1. Número de Vendas
# 2. Ticket Médio
# 3. LTV ( Long Time Value )
# 4. Recência Média
# 5. Basket Size Médio
# 6. Markup médio

# %% [markdown]
# ### 3.3 - Métricas de Custo

# %% [markdown]
# 1. CAC ( Custo de aquisição de Clientes )
# 2. Desconto médio
# 3. Custo de Produção
# 4. Taxa de devolução
# 5. Custos Fixos ( Folha de pagamento, escritório, softwares )
# 6. Impostos
