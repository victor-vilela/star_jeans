# %% [markdown]
# # Modulo 06 - Módulo Avançado

# %% [markdown]
# ## Apply, Map, Lambda - Parte II

# %%
import pandas as pd
path = 'products_hm.csv'
df = pd.read_csv( path )
# product price - remove $
#df['product_price'] = df['product_price'].apply( lambda x: x.replace( '$ ','' ) if pd.notnull( x ) else x )
# product price - remove $ all columns
#df['product_price'] = df.apply( lambda x: x['product_price'].replace( '$ ', '') if pd.notnull( x['product_price'] ) else x, axis=1 )
## product price - remove $ - both conditional
#df['product_price'] = df[['product_price', 'color_name']].apply( lambda x: x['product_price'].replace('$ ', '')
# if (pd.notnull(x['product_price']) ) & (x['color_name']=='Gray')
# else x, axis=1 )
# product price - remove $ - sequential conditional
# df.loc[0,'product_color'] = 'Gray'
# df['product_price2'] = df[['product_price', 'product_color']].apply(lambda x: x if pd.isnull( x['product_price'] ) else x['product_price'].replace( '$ ', '') if x['product_color'] == 'Gray' else x, axis=1 )
df.head()
# Out:
#    product_id   product_name   product_category product_price  \
# 0  1074475001    Loose Jeans    men_jeans_loose       $ 39.99
# 1  1071707001  Relaxed Jeans  men_jeans_relaxed       $ 29.99
# 2  1071707001  Relaxed Jeans  men_jeans_relaxed       $ 29.99
# 3  1071707001  Relaxed Jeans  men_jeans_relaxed       $ 29.99
# 4  1071707001  Relaxed Jeans  men_jeans_relaxed       $ 29.99
#
#          scrapy_datetime  style_id  color_id     product_color  \
# 0   2022-05-23 20:56:47    1074475         1              Gray
# 1   2022-05-23 20:56:47    1071707         1  Light denim blue
# 2   2022-05-23 20:56:47    1071707         1  Light denim blue
# 3   2022-05-23 20:56:47    1071707         1  Light denim blue
# 4   2022-05-23 20:56:47    1071707         1  Light denim blue
#
#                       Care instructions                 Composition  ...  \
# 0                                   NaN                         NaN  ...
# ...

# %%
df.loc[1,'product_price']
# Out:
# product_price             $ 29.99
# product_color    Light denim blue
# Name: 1, dtype: object
