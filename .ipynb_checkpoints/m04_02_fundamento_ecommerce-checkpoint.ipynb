# %% [markdown]
# # Modulo 04 - Modelo de Negócio e Métricas

# %% [markdown]
# ## 2 - O fundamento de um e-commerce

# %% [markdown]
# ### 2.1 - Nível de consciência dos consumidores

# %%
from IPython.display import Image
PATH = 'photos/piramide_consciencia.PNG'
Image( filename = PATH, width=600, height=400)

# %% [markdown]
# ### 2.2 -  O famoso fúnil de vendas

# %%
from IPython.display import Image
PATH = 'photos/funil_de_vendas.PNG'
Image( filename = PATH, width=800, height=400)
