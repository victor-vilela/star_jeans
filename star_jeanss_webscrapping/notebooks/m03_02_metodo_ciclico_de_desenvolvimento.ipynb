# %% [markdown]
# # Modulo 03 - Método Cíclico de Desenvolvimento

# %% [markdown]
# ## O método cíclico de desenvolvimento

# %% [markdown]
# ## As etapas de um projeto de Dados

# %% [markdown]
# 1. Questão de Negócio
# 2. Entendimento de Negócio.
# 3. Coleta de dados.
# 4. Limpeza de dados.
# 5. Exploração de dados.
# 6. Modelagem de dados.
# 7. Aplicação dos algoritmos de ML.
# 8. Avaliação de performance dos algoritmos
# 9. Publicação do modelo em Produção.

# %% [markdown]
# ## O método CRISP-DS de desenvolvimento

# %%
from IPython.display import Image
PATH = 'photos/metodo-ciclico.PNG'
Image( filename = PATH, width=900, height=900)
